# %%
import os
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from tensorflow.keras.utils import load_img,img_to_array,array_to_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# cration of image datagen.
datagen = ImageDataGenerator(rotation_range=40,
                             width_shift_range=0.2,
                             zoom_range=0.2,
                             height_shift_range=0.2,
                             shear_range=0.2,
                             horizontal_flip=True,
                             fill_mode='nearest')

# %%
x=load_img('image path')
x
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F14946C0070>

# %%
# creation of folder for each categories
os.chdir('path to folder where all the photoes will be saved')
n=0
for i in os.listdir('folder of images that will be going to augmented'): # creation of folders of each category 
  os.mkdir(i)
  folder_path = os.listdir('category of images that will be going to augmented')[n] # getting images from each category
  print("******************************")
  print(i)
  for j in os.listdir(folder_path):
    print(j)
    rushi+=1
  if n<len(i):
    n+=1
  else:
    break
print("*****")
print(n)
print(os.getcwd())
print("*****")
# Out:
# ******************************
# Amoeba
# ******************************
# Euglena
# ******************************
# Hydra
# ******************************
# Paramecium
# ******************************
# Rod_bacteria
# ******************************
# Spherical_bacteria
# ******************************
# Spiral_bacteria
# ******************************
# Yeast
# *****
# 7
# /content/drive/MyDrive/Classification/temp/finalphotoes
# *****
# 0

# %%
os.chdir('path to folder where all the photoes will be saved')
# Out:
# /content

# %%
for n in os.listdir('path of new created folder'):
  final_path = f'folder/{n}' # for all the categories.
  print("***************************************")
  print(n)
  print(final_path)
  print("***************************************")

  # Loop for images to be augmented.
  for item in os.listdir(f'path of root folder/{n}'):
    print("***************************************")
    print(item)

    img = load_img(f'path of root folder/{n}/{item}')
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0

    #  This loop will be created 20 augmented images of each images.
    for batch in datagen.flow(x, batch_size=1, save_to_dir=final_path, save_prefix=f'{n}', save_format='jpg'):
      i+=1
      if i>20:
        break
    

    print(f"Done for {item}")
    print("***************************************")
    print(f'{n}')

# %%
print("All images are created successfully.")
# Out:
# All images are created successfully.
